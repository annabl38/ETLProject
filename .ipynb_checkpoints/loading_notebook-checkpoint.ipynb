# %%
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector

# %%
gpu_path="./GPU_Final.csv"
gpu_db= pd.read_csv(gpu_path)
gpu_db= gpu_db.copy()
gpu_db.head()
# Out:
#   Year_Quarter  Average_Q_Price
# 0        07'Q4       349.000000
# 1        08'Q1       200.000000
# 2        08'Q2       449.000000
# 3        08'Q3       181.200000
# 4        08'Q4       262.666667

# %%
cpu_path="./CPU_Final.csv"
cpu_db= pd.read_csv(cpu_path)
cpu_db= cpu_db.copy()
cpu_db.head()
# Out:
#   clean_date  Recommended_Customer_Price
# 0      05'Q1                       93.00
# 1      05'Q2                      271.00
# 2      06'Q1                      516.60
# 3      06'Q2                      342.25
# 4      06'Q3                      114.20

# %%
ltc_path="./LTC_Final.csv"
ltc_db= pd.read_csv(ltc_path)
ltc_db= ltc_db.copy()
ltc_db.head()
# Out:
#    Unnamed: 0  LTC_price_close Year_quarter  LTC_trade_count  LTC_trade_volume
# 0           0           2.6002        13'Q2              992      4.599762e+04
# 1           1           2.2500        13'Q3             1515      1.098808e+05
# 2           2          23.8000        13'Q4            54092      1.411151e+06
# 3           3          12.7800        14'Q1           101479      1.769846e+06
# 4           4           8.9000        14'Q2           668282      8.771386e+06

# %%
btc_path="./BTC_Final.csv"
btc_db= pd.read_csv(btc_path)
btc_db= btc_db.copy()
btc_db.head()
# Out:
#    Unnamed: 0  BTC_price_close Year_quarter  BTC_trade_count  BTC_trade_volume
# 0           0          0.06190        10'Q3             2665      4.704097e+05
# 1           1          0.30000        10'Q4             6092      2.195828e+06
# 2           2          0.78461        11'Q1             8406      9.883464e+05
# 3           3         16.10096        11'Q2           205917      3.173722e+06
# 4           4          5.14009        11'Q3           536900      3.814916e+06

# %%
eth_path="./ETH_Final.csv"
eth_db= pd.read_csv(eth_path)
eth_db= eth_db.copy()
eth_db.head()
# Out:
#    Unnamed: 0  ETH_price_close Year_quarter  ETH_trade_count  ETH_trade_volume
# 0           0           11.386        16'Q1            24237      2.805613e+05
# 1           1           12.402        16'Q2           377311      9.545457e+06
# 2           2           13.230        16'Q3           534776      1.124118e+07
# 3           3            8.160        16'Q4           617786      8.841577e+06
# 4           4           49.724        17'Q1          1873590      2.977598e+07

# %%
xrp_path="./XRP_Final.csv"
xrp_db= pd.read_csv(xrp_path)
xrp_db= xrp_db.copy()
xrp_db.head()
# Out:
#    Unnamed: 0  XRP_price_close Year_quarter  XRP_trade_count  XRP_trade_volume
# 0           0         0.003816        14'Q2              230      4.624811e+02
# 1           1         0.004998        14'Q3               57      2.119292e+02
# 2           2         0.021400        17'Q1            26880      6.922213e+08
# 3           3         0.248690        17'Q2           709649      2.726098e+09
# 4           4         0.199030        17'Q3          1490365      3.518229e+09

# %%
engine = create_engine('mysql+mysqlconnector://root:anna@localhost/etl_project')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     178         try:
# --> 179             self._cmysql.connect(**cnx_kwargs)
#     180         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Unknown database 'etl_project'
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     171     if HAVE_CEXT and not use_pure:
# --> 172         return CMySQLConnection(*args, **kwargs)
#     173     return MySQLConnection(*args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\connection_cext.py in __init__(self, **kwargs)
#      77         if kwargs:
# ---> 78             self.connect(**kwargs)
#      79
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     735         self.disconnect()
# --> 736         self._open_connection()
#     737         self._post_connection()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     181             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
# --> 182                                              sqlstate=exc.sqlstate)
#     183         self._do_handshake()
#
# ProgrammingError: 1049 (42000): Unknown database 'etl_project'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2134         """
#    2135
# -> 2136         with self._optional_conn_ctx_manager(connection) as conn:
#    2137             if not schema:
#    2138                 schema = self.dialect.default_schema_name
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    1930     def _optional_conn_ctx_manager(self, connection=None):
#    1931         if connection is None:
# -> 1932             with self.contextual_connect() as conn:
#    1933                 yield conn
#    1934         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     398         """
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#     402         try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     527     @classmethod
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#     531             dbapi_connection = rec.get_connection()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     345         """Called by subclasses to create a new ConnectionRecord."""
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#     349     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     472         self.__pool = pool
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#     476
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     170
#     171     if HAVE_CEXT and not use_pure:
# --> 172         return CMySQLConnection(*args, **kwargs)
#     173     return MySQLConnection(*args, **kwargs)
#     174 Connect = connect  # pylint: disable=C0103
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\connection_cext.py in __init__(self, **kwargs)
#      76
#      77         if kwargs:
# ---> 78             self.connect(**kwargs)
#      79
#      80     def _do_handshake(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     734
#     735         self.disconnect()
# --> 736         self._open_connection()
#     737         self._post_connection()
#     738
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     180         except MySQLInterfaceError as exc:
#     181             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
# --> 182                                              sqlstate=exc.sqlstate)
#     183         self._do_handshake()
#     184
#
# ProgrammingError: (mysql.connector.errors.ProgrammingError) 1049 (42000): Unknown database 'etl_project' (Background on this error at: http://sqlalche.me/e/f405)

# %%
btc_db.to_sql(name='bitcoin', con=engine, if_exists='append', index=False)
eth_db.to_sql(name='etherium', con=engine, if_exists='append', index=False)
gpu_db.to_sql(name='gpu_prices', con=engine, if_exists='append', index=False)
ltc_db.to_sql(name='litecoin', con=engine, if_exists='append', index=False)
xrp_db.to_sql(name='ripple', con=engine, if_exists='append', index=False)
cpu_db.to_sql(name='cpu_prices', con=engine, if_exists='append', index=False)
